# %% [markdown]
# <a href="https://colab.research.google.com/github/srajalcodes/DIP-DigitalImageProcessing/blob/main/Color_Based_Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import pyplot as plt

# %%
#Loading image
image = cv2.imread('/content/images-1.jpeg')
plt.imshow(image)
plt.show()

# %%
# Convert BGR to HSV
image_hsv=cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
lower_red=np.array([100,50,50])
upper_red=np.array([180,255,255])

# %%
# Creates a binary mask based on the HSV image

mask=cv2.inRange(image_hsv,lower_red,upper_red)

# %%
# # Display the masked RGB image

image_bgr_masked=cv2.bitwise_and(image,image,mask=mask)
image_rgb=cv2.cvtColor(image_bgr_masked,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)
plt.show()
